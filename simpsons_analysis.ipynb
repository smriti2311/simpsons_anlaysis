# %% [markdown]
# ### **Test Data**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_df=pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#     id  imdb_votes  ...                        title  us_viewers_in_millions
# 0  207      1013.0  ...       Treehouse of Horror IX                     8.5
# 1  273       651.0  ...  A Hunka Hunka Burns in Love                    13.4
# 2   36      1798.0  ...             Stark Raving Dad                    22.9
# 3  252       731.0  ...         Lisa the Tree Hugger                    14.9
# 4  327       568.0  ...  The Ziff Who Came to Dinner                    10.7
#
# [5 rows x 8 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      239 non-null    int64
#  1   imdb_votes              239 non-null    float64
#  2   number_in_season        239 non-null    int64
#  3   number_in_series        239 non-null    int64
#  4   original_air_date       239 non-null    object
#  5   season                  239 non-null    int64
#  6   title                   239 non-null    object
#  7   us_viewers_in_millions  239 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 15.1+ KB

# %%
test_df.describe()
# Out:
#                id   imdb_votes  ...      season  us_viewers_in_millions
# count  239.000000   239.000000  ...  239.000000              239.000000
# mean   307.058577   823.753138  ...   14.389121               11.731130
# std    172.584009   392.398905  ...    7.713573                6.448615
# min      8.000000   227.000000  ...    1.000000                2.320000
# 25%    158.000000   554.000000  ...    8.000000                6.725000
# 50%    314.000000   672.000000  ...   15.000000               10.390000
# 75%    462.000000  1086.500000  ...   21.000000               15.200000
# max    595.000000  2439.000000  ...   27.000000               33.600000
#
# [8 rows x 6 columns]

# %% [markdown]
# **Total number of seasons in test dataset = 27**

# %%
# total number of seasons
test_df['season'].unique()
# Out:
# array([10, 13,  3, 12, 15, 25,  5, 21,  2, 27,  4, 20,  6, 14, 18, 16, 22,
#        23,  7, 19,  9, 17, 11, 26,  8, 24,  1])

# %%
t_temp=pd.DataFrame()
t_temp['number_in_season']=test_df['number_in_season']
t_temp['season']=test_df['season']
t_temp
# Out:
#      number_in_season  season
# 0                   4      10
# 1                   4      13
# 2                   1       3
# 3                   4      12
# 4                  14      15
# ..                ...     ...
# 234                 9      10
# 235                11      24
# 236                20       3
# 237                 2      19
# 238                 2      26
#
# [239 rows x 2 columns]

# %%
train_df=pd.read_csv("train.csv")
train_df.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  imdb_score
# 0  418       585.0  ...                    6.18         7.0
# 1  156      1085.0  ...                   17.00         8.0
# 2  210       909.0  ...                    8.00         8.0
# 3  249       829.0  ...                   13.20         7.6
# 4   65      1293.0  ...                   20.10         8.2
#
# [5 rows x 9 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      358 non-null    int64
#  1   imdb_votes              358 non-null    float64
#  2   number_in_season        358 non-null    int64
#  3   number_in_series        358 non-null    int64
#  4   original_air_date       358 non-null    object
#  5   season                  358 non-null    int64
#  6   title                   358 non-null    object
#  7   us_viewers_in_millions  355 non-null    float64
#  8   imdb_score              358 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 25.3+ KB

# %%
t=t_temp.groupby('number_in_season', sort=True)
t.head()
# Out:
#      number_in_season  season
# 0                   4      10
# 1                   4      13
# 2                   1       3
# 3                   4      12
# 4                  14      15
# ..                ...     ...
# 167                23       8
# 181                 5       3
# 197                25       8
# 204                24       3
# 231                23      21
#
# [120 rows x 2 columns]

# %%
#average no. of episodes per season
t1=test_df.groupby('season',sort=True)
t1.head()
# Out:
#       id  imdb_votes  ...                           title  us_viewers_in_millions
# 0    207      1013.0  ...          Treehouse of Horror IX                    8.50
# 1    273       651.0  ...     A Hunka Hunka Burns in Love                   13.40
# 2     36      1798.0  ...                Stark Raving Dad                   22.90
# 3    252       731.0  ...            Lisa the Tree Hugger                   14.90
# 4    327       568.0  ...     The Ziff Who Came to Dinner                   10.70
# ..   ...         ...  ...                             ...                     ...
# 166  492       712.0  ...                    The Book Job                    5.77
# 168  367       535.0  ...  We're on the Road to D'ohwhere                    9.04
# 171  517       411.0  ...       Homer Goes to Prep School                    8.97
# 176  529       460.0  ...                The Saga of Carl                    4.01
# ...

# %% [markdown]
# **Grouped the test data according to the seasons and extracted their respective imdb votes per season**

# %%
t2=pd.DataFrame()
t2=test_df['imdb_votes'].groupby(test_df['season'])

# %% [markdown]
# ### **Total number of votes for all episodes in respective seasons in the test data**

# %%
# tt2=pd.DataFrame()
tt2=t2.sum()
tt2
# Out:
# season
# 1      3296.0
# 2     14859.0
# 3     14512.0
# 4      9390.0
# 5     10777.0
# 6     15419.0
# 7      8273.0
# 8     13717.0
# 9      8830.0
# 10    11625.0
# 11     1696.0
# 12     5379.0
# 13     9937.0
# 14     3794.0
# 15     7149.0
# 16     5971.0
# 17     3339.0
# 18     6363.0
# 19     5590.0
# 20     6241.0
# 21     3766.0
# 22     6701.0
# 23     4556.0
# 24     2985.0
# 25     4090.0
# 26     5067.0
# 27     3555.0
# Name: imdb_votes, dtype: float64

# %%
tt2=pd.DataFrame(tt2)
tt2
# Out:
#         imdb_votes
# season
# 1           3296.0
# 2          14859.0
# 3          14512.0
# 4           9390.0
# 5          10777.0
# 6          15419.0
# 7           8273.0
# 8          13717.0
# 9           8830.0
# 10         11625.0
# 11          1696.0
# 12          5379.0
# 13          9937.0
# 14          3794.0
# 15          7149.0
# 16          5971.0
# 17          3339.0
# 18          6363.0
# 19          5590.0
# 20          6241.0
# 21          3766.0
# 22          6701.0
# 23          4556.0
# 24          2985.0
# 25          4090.0
# 26          5067.0
# 27          3555.0

# %%
plt.bar(tt2.index,tt2['imdb_votes'])
plt.xlabel('Seasons')
plt.ylabel('Max imdb votes per season')
plt.show()

# %% [markdown]
#  **The above bar plot shows the total imdb votes per season. We can see, season 6 received the maximum imdb votes out of all 27 seasons**

# %%
test_df["season"]
# Out:
# 0      10
# 1      13
# 2       3
# 3      12
# 4      15
#        ..
# 234    10
# 235    24
# 236     3
# 237    19
# 238    26
# Name: season, Length: 239, dtype: int64

# %%
test_df["season"].value_counts()
# Out:
# 13    15
# 10    13
# 22    13
# 6     12
# 26    12
# 15    12
# 3     11
# 27    10
# 2     10
# 8     10
# 16    10
# 20    10
# 18     9
# 5      9
# 19     8
# 23     8
# 9      8
# 25     8
# 4      7
# 12     7
# 21     7
# 24     7
# 7      7
# 14     6
# 17     6
# 11     2
# 1      2
# Name: season, dtype: int64

# %%
#total episodes per season in this test dataset
test_df["season"].value_counts().sort_index()
# Out:
# 1      2
# 2     10
# 3     11
# 4      7
# 5      9
# 6     12
# 7      7
# 8     10
# 9      8
# 10    13
# 11     2
# 12     7
# 13    15
# 14     6
# 15    12
# 16    10
# 17     6
# 18     9
# 19     8
# 20    10
# 21     7
# 22    13
# 23     8
# 24     7
# 25     8
# 26    12
# 27    10
# Name: season, dtype: int64

# %%
#count of episodes per season in the dataset
sns.countplot(x="season",data=test_df)

# %% [markdown]
#  **The above countplot shows the number of episodes per season in the test data and Season 13 had the maximum number of episodes and season 1 had the lowest about 2 episodes, similar to season 11**

# %% [markdown]
# **A histogram for the total imdb votes in all 27 seasons**

# %%
test_df["imdb_votes"].hist(bins=20)
plt.show()

# %% [markdown]
# ### **Similar analysis for train dataset**

# %%
train_df=pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  imdb_score
# 0  418       585.0  ...                    6.18         7.0
# 1  156      1085.0  ...                   17.00         8.0
# 2  210       909.0  ...                    8.00         8.0
# 3  249       829.0  ...                   13.20         7.6
# 4   65      1293.0  ...                   20.10         8.2
#
# [5 rows x 9 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      358 non-null    int64
#  1   imdb_votes              358 non-null    float64
#  2   number_in_season        358 non-null    int64
#  3   number_in_series        358 non-null    int64
#  4   original_air_date       358 non-null    object
#  5   season                  358 non-null    int64
#  6   title                   358 non-null    object
#  7   us_viewers_in_millions  355 non-null    float64
#  8   imdb_score              358 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 25.3+ KB

# %%
train_df.describe()
# Out:
#                id   imdb_votes  ...  us_viewers_in_millions  imdb_score
# count  358.000000   358.000000  ...              355.000000  358.000000
# mean   293.620112   838.114525  ...               11.917972    7.388547
# std    172.447600   399.025256  ...                6.398973    0.729266
# min      1.000000   104.000000  ...                2.520000    4.500000
# 25%    145.250000   563.750000  ...                7.250000    6.900000
# 50%    293.000000   715.500000  ...               10.300000    7.300000
# 75%    442.750000  1099.500000  ...               15.200000    8.000000
# max    597.000000  3734.000000  ...               33.500000    9.100000
#
# [8 rows x 7 columns]

# %%
t3=pd.DataFrame()
t3=train_df['imdb_votes'].groupby(train_df['season'])

# %%
tt3=t3.sum()
tt3
# Out:
# season
# 1     20356.0
# 2     16303.0
# 3     16974.0
# 4     20255.0
# 5     17043.0
# 6     15462.0
# 7     21341.0
# 8     17122.0
# 9     16504.0
# 10     8615.0
# 11    15731.0
# 12    10825.0
# 13     4885.0
# 14     9996.0
# 15     6038.0
# 16     6135.0
# 17     9874.0
# 18     8063.0
# 19     7973.0
# 20     7111.0
# 21     8756.0
# 22     4606.0
# 23     8196.0
# 24     6703.0
# 25     6602.0
# 26     4874.0
# 27     3598.0
# 28      104.0
# Name: imdb_votes, dtype: float64

# %% [markdown]
#  **Total votes per season**

# %%
tt3=pd.DataFrame(tt3)
tt3
# Out:
#         imdb_votes
# season
# 1          20356.0
# 2          16303.0
# 3          16974.0
# 4          20255.0
# 5          17043.0
# 6          15462.0
# 7          21341.0
# 8          17122.0
# 9          16504.0
# 10          8615.0
# 11         15731.0
# 12         10825.0
# 13          4885.0
# 14          9996.0
# 15          6038.0
# 16          6135.0
# 17          9874.0
# 18          8063.0
# 19          7973.0
# 20          7111.0
# 21          8756.0
# 22          4606.0
# 23          8196.0
# 24          6703.0
# 25          6602.0
# 26          4874.0
# 27          3598.0
# 28           104.0

# %% [markdown]
#  **A bar plot for the same**

# %%
plt.bar(tt3.index,tt3['imdb_votes'])
plt.xlabel('Seasons')
plt.ylabel('Max imdb votes per season')
plt.show()
# add values to each bar

# %% [markdown]
#  **A barplot for the viewership of every season in the US**

# %%
sns.barplot(x="season", y="us_viewers_in_millions", data=test_df)
plt.show()

# %% [markdown]
#  **Season 1 had the maximum viewership amongst all 27 seasons, whereas season 27 received the least viewership**

# %%
t4=pd.DataFrame()
t4=train_df['imdb_score'].groupby(train_df['season'])

# %% [markdown]
# **Average imdb score per season**

# %%
tt4=t4.mean()
tt4
# Out:
# season
# 1     7.772727
# 2     7.983333
# 3     8.161538
# 4     8.260000
# 5     8.369231
# 6     8.192308
# 7     8.350000
# 8     8.180000
# 9     7.900000
# 10    7.520000
# 11    7.260000
# 12    7.335714
# 13    7.171429
# 14    7.125000
# 15    7.160000
# 16    7.054545
# 17    6.856250
# 18    6.915385
# 19    7.033333
# 20    6.854545
# 21    6.793750
# 22    6.822222
# 23    6.607143
# 24    6.753333
# 25    6.800000
# 26    6.760000
# 27    6.833333
# 28    6.600000
# Name: imdb_score, dtype: float64

# %%
tt4=pd.DataFrame(tt4)
tt4
# Out:
#         imdb_score
# season
# 1         7.772727
# 2         7.983333
# 3         8.161538
# 4         8.260000
# 5         8.369231
# 6         8.192308
# 7         8.350000
# 8         8.180000
# 9         7.900000
# 10        7.520000
# 11        7.260000
# 12        7.335714
# 13        7.171429
# 14        7.125000
# 15        7.160000
# 16        7.054545
# 17        6.856250
# 18        6.915385
# 19        7.033333
# 20        6.854545
# 21        6.793750
# 22        6.822222
# 23        6.607143
# 24        6.753333
# 25        6.800000
# 26        6.760000
# 27        6.833333
# 28        6.600000

# %%
ax=sns.barplot(x=tt4.index,y=tt4['imdb_score'],data=tt4)
ax.set(xlabel='Season', ylabel='Avg imdb score')
plt.show()
# add values to each bar

# %% [markdown]
#  **The average imdb score for all 27 seasons has been 7 or more than that which suggests that the show has been a favourite of the US audience**

# %%
sns.barplot(x="season", y="us_viewers_in_millions", data=train_df)
plt.show()

# %% [markdown]
# ### **Now merging Test and Train dataset**

# %%
merge=[test_df,train_df]
mergedf=pd.concat(merge)

# %% [markdown]
# ### **EDA on merged dataset**

# %%
mergedf.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  imdb_score
# 0  207      1013.0  ...                     8.5         NaN
# 1  273       651.0  ...                    13.4         NaN
# 2   36      1798.0  ...                    22.9         NaN
# 3  252       731.0  ...                    14.9         NaN
# 4  327       568.0  ...                    10.7         NaN
#
# [5 rows x 9 columns]

# %%
mergedf['imdb_score'].isnull().sum() 
# equal to 239 rows present in test dataset as this column doesn't exist in test df
# thus dropping this column
# Out:
# 239

# %%
mergedf=mergedf.drop('imdb_score',axis=1)

# %%
mergedf.isnull().sum()
# Out:
# id                        0
# imdb_votes                0
# number_in_season          0
# number_in_series          0
# original_air_date         0
# season                    0
# title                     0
# us_viewers_in_millions    3
# dtype: int64

# %%
mergedf['us_viewers_in_millions']=mergedf['us_viewers_in_millions'].fillna(mergedf['us_viewers_in_millions'].mean())

# %%
mergedf.isnull().sum()
# Out:
# id                        0
# imdb_votes                0
# number_in_season          0
# number_in_series          0
# original_air_date         0
# season                    0
# title                     0
# us_viewers_in_millions    0
# dtype: int64

# %%
mergedf.head()
# Out:
#     id  imdb_votes  ...                        title  us_viewers_in_millions
# 0  207      1013.0  ...       Treehouse of Horror IX                     8.5
# 1  273       651.0  ...  A Hunka Hunka Burns in Love                    13.4
# 2   36      1798.0  ...             Stark Raving Dad                    22.9
# 3  252       731.0  ...         Lisa the Tree Hugger                    14.9
# 4  327       568.0  ...  The Ziff Who Came to Dinner                    10.7
#
# [5 rows x 8 columns]

# %%
mergedf.corr()
# Out:
#                               id  imdb_votes  ...    season  us_viewers_in_millions
# id                      1.000000   -0.849787  ...  0.999071               -0.854458
# imdb_votes             -0.849787    1.000000  ... -0.841633                0.785885
# number_in_season        0.011935   -0.103570  ... -0.025169               -0.154905
# number_in_series        1.000000   -0.849787  ...  0.999071               -0.854458
# season                  0.999071   -0.841633  ...  1.000000               -0.845100
# us_viewers_in_millions -0.854458    0.785885  ... -0.845100                1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(mergedf.corr(), annot= True)
plt.show()

# %% [markdown]
# ### **Plots on merged dataset**

# %%
sns.countplot(x="season", data=mergedf)
plt.show()

# %%
sns.barplot(x="season", y="us_viewers_in_millions", data=mergedf)

# %%
sns.boxplot(x="season", y="us_viewers_in_millions", data=mergedf)

# %% [markdown]
# ### **Feature Added**

# %%
mergedf['title_len'] = mergedf['title'].apply(lambda x: len(x))

# %%
mergedf.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  title_len
# 0  207      1013.0  ...                     8.5         22
# 1  273       651.0  ...                    13.4         27
# 2   36      1798.0  ...                    22.9         16
# 3  252       731.0  ...                    14.9         20
# 4  327       568.0  ...                    10.7         27
#
# [5 rows x 9 columns]

# %% [markdown]
#  **Year extracted from the original air date**

# %%
mergedf['original_air_date']=pd.to_datetime(mergedf['original_air_date'])
# mergedf['month'] = mergedf['original_air_date'].dt.month
# df['year'] = df['datetime_utc'].dt.year

# %%
mergedf.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  title_len
# 0  207      1013.0  ...                     8.5         22
# 1  273       651.0  ...                    13.4         27
# 2   36      1798.0  ...                    22.9         16
# 3  252       731.0  ...                    14.9         20
# 4  327       568.0  ...                    10.7         27
#
# [5 rows x 9 columns]

# %%
# mergedf=mergedf.drop('date',axis=1)

# %%
mergedf.head()
# Out:
#     id  imdb_votes  ...  us_viewers_in_millions  title_len
# 0  207      1013.0  ...                     8.5         22
# 1  273       651.0  ...                    13.4         27
# 2   36      1798.0  ...                    22.9         16
# 3  252       731.0  ...                    14.9         20
# 4  327       568.0  ...                    10.7         27
#
# [5 rows x 9 columns]

# %%
mergedf['month'] = mergedf['original_air_date'].dt.month
mergedf['year'] = mergedf['original_air_date'].dt.year

# %%
mergedf.head()
# Out:
#     id  imdb_votes  number_in_season  ...  title_len month  year
# 0  207      1013.0                 4  ...         22    10  1998
# 1  273       651.0                 4  ...         27    12  2001
# 2   36      1798.0                 1  ...         16     9  1991
# 3  252       731.0                 4  ...         20    11  2000
# 4  327       568.0                14  ...         27     3  2004
#
# [5 rows x 11 columns]

# %%
sns.countplot(x=mergedf['month'],data=mergedf)
plt.show()

# %% [markdown]
#  **The above countplot shows the maximum number of releases have been made in which month whereas the month of June-July have been least targeted to air the episodes whereas November and May have been targeted the most**

# %%
# sns.countplot(x=mergedf['year'],data=mergedf)
plt.figure(figsize=(20,5))
ax = sns.countplot(x=mergedf['year'], data=mergedf)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
#  **A count plot of year wise release of the episodes**

# %% [markdown]
# ### **EDA on the scripts dataset**

# %%
scripts=pd.read_csv('script_lines.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
scripts.head()
# Out:
#      id  ...                                    normalized_text
# 0  9549  ...  no actually it was a little of both sometimes ...
# 1  9550  ...                                wheres mr bergstrom
# 2  9551  ...  i dont know although id sure like to talk to h...
# 3  9552  ...                          that life is worth living
# 4  9553  ...  the polls will be open from now until the end ...
#
# [5 rows x 11 columns]

# %%
scripts['totalwords'] = scripts['normalized_text'].str.split().str.len()

# %%
scripts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158248 entries, 0 to 158247
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  158248 non-null  int64
#  1   episode_id          158248 non-null  int64
#  2   number              158248 non-null  int64
#  3   raw_text            158248 non-null  object
#  4   speaking_line       158248 non-null  object
#  5   character_id        140727 non-null  object
#  6   location_id         157841 non-null  float64
#  7   raw_character_text  140726 non-null  object
#  8   raw_location_text   157840 non-null  object
#  9   spoken_words        132089 non-null  object
#  10  normalized_text     132064 non-null  object
#  11  totalwords          132064 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 14.5+ MB

# %%
scripts.head()
# Out:
#      id  ...  totalwords
# 0  9549  ...        31.0
# 1  9550  ...         3.0
# 2  9551  ...        22.0
# 3  9552  ...         5.0
# 4  9553  ...        33.0
#
# [5 rows x 12 columns]

# %%
import re
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import matplotlib.image as mpimg

from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer
from plotly import tools
from plotly.offline import init_notebook_mode,iplot,plot
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# ### **Normalizing the text spoken a little more to grab the most frequent words spoken by characters**

# %%
description_list=[]
for description in scripts['normalized_text']:
    description=re.sub("[^a-zA-Z]", " ", str(description))
    description=description.lower()
    description=nltk.word_tokenize(description)
    description=[word for word in description if not word in set(stopwords.words("english"))]
    lemma=nltk.WordNetLemmatizer()
    description=[lemma.lemmatize(word) for word in description]
    description=" ".join(description)
    description_list.append(description)
scripts["normalized_text_new"]=description_list
scripts.head()
# Out:
#      id  ...                                normalized_text_new
# 0  9549  ...  actually little sometimes disease magazine new...
# 1  9550  ...                                wheres mr bergstrom
# 2  9551  ...  dont know although id sure like talk didnt tou...
# 3  9552  ...                                  life worth living
# 4  9553  ...  poll open end recess case decided put thought ...
#
# [5 rows x 13 columns]

# %%
y=scripts["location_id"].unique()
len(y)
# Out:
# 4460

# %%
fig = plt.figure(figsize=(17,8))
ax = fig.add_subplot(111)
step = 5
bin_range = np.arange(0, 120, step)
out, bins  = pd.cut(scripts['totalwords'], bins=bin_range, include_lowest=True, right=False, retbins=True)
out.value_counts(sort=False).plot.bar(color='#1414B4')
plt.title('Line Length Counts', size=25)
plt.tick_params(labelsize=16)
plt.xlabel('Bins for Number of words in lines', size=20)
plt.ylabel('Lines with that many words', size=20)
# Out:
# Text(0, 0.5, 'Lines with that many words')

# %%
plt.close('all')
print('average words per line :', round(scripts['totalwords'].mean(), 2))
print('\n')
print('first episode featured: ', scripts.episode_id.min(), '     last episode featured: ', scripts.episode_id.max())
print('\n')
print('lines with more than 100 words: ', scripts[scripts.totalwords >= 100].speaking_line.count())
print('\n')
print('characters with more than 100 lines > AKA "Who\'s speaking for that long?"')
print(scripts[scripts.totalwords >= 100][['raw_character_text', 'episode_id']])
# Out:
# average words per line : 9.89
#
#
# first episode featured:  1      last episode featured:  568
#
#
# lines with more than 100 words:  11
#
#
# characters with more than 100 lines > AKA "Who's speaking for that long?"
#        raw_character_text  episode_id
# 6319              Singers          52
# 13084      Grampa Simpson          76
# 18231         James Woods          94
# 18747       Kent Brockman          96
# 42166       Homer Simpson         184
# 69514         Moe Szyslak         274
# 89997     David Silverman         347
# 123992       Randy Newman         478
# 125143    Ewell Freestone         482
# 145638        SAMMY HAGAR         560
# 151831      Homer Simpson          10

# %%
sortscripts = scripts.groupby('episode_id').count()
sortscripts.head()
# Out:
#              id  number  ...  totalwords  normalized_text_new
# episode_id               ...
# 1           377     377  ...         333                  377
# 2           294     294  ...         271                  294
# 3           250     250  ...         207                  250
# 4           341     341  ...         304                  341
# 5           323     323  ...         283                  323
#
# [5 rows x 12 columns]

# %%
fig = plt.figure(figsize=(18, 8))
ax = fig.add_subplot(111)
ax.plot(sortscripts.speaking_line, color='#1414B4')
ax.set_title('Lines Per Episode', size=25)
ax.tick_params(labelsize=16)
ax.set_xlabel('Episode ID', size=20)
ax.set_ylabel('Lines in Episode', size=20)
plt.show()

# %% [markdown]
#  **A plot to find out the number of lines spoken in all by all characters inclusive per episode**

# %%
for i,row in scripts.iterrows():
    print(row['character_id'],row['raw_character_text'])
# Out:
# Streaming output truncated to the last 5000 lines.
# 8 Bart Simpson
# 2 Homer Simpson
# 2 Homer Simpson
# 8 Bart Simpson
# 2 Homer Simpson
# 1 Marge Simpson
# 2 Homer Simpson
# 1 Marge Simpson
# 9 Lisa Simpson
# 2 Homer Simpson
# 1 Marge Simpson
# nan nan
# 14 Waylon Smithers
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 256 Karl
# 2 Homer Simpson
# 15 C. Montgomery Burns
# 15 C. Montgomery Burns
# 14 Waylon Smithers
# 2 Homer Simpson
# 15 C. Montgomery Burns
# 2 Homer Simpson
# 2 Homer Simpson
# 14 Waylon Smithers
# 14 Waylon Smithers
# 15 C. Montgomery Burns
# 2 Homer Simpson
# 15 C. Montgomery Burns
# 2 Homer Simpson
# 15 C. Montgomery Burns
# 15 C. Montgomery Burns
# 2 Homer Simpson
# 15 C. Montgomery Burns
# 2 Homer Simpson
# nan nan
# 1 Marge Simpson
# 2 Homer Simpson
# 1 Marge Simpson
# 2 Homer Simpson
# 1 Marge Simpson
# ...

# %%
val_homer=[]
val_bart=[]
val_marge=[]
val_lisa=[]

for i,row in scripts.iterrows():
    val = row['normalized_text_new']
    if row['character_id'] == 2:
        val_homer.append(val)
    elif row['character_id']== 8:
        val_bart.append(val)
    elif row['character_id'] == 1:
        val_marge.append(val)
    elif row['character_id']== 9:
        val_lisa.append(val)

# %%
pat = r'\b(?:{})\b'.format('|'.join(stop))
def text_cleaning(val_list):
    df1 = pd.DataFrame(val_list,columns =['normalized_text_new']).dropna()
    df1["normalized_text_new"] = df1["normalized_text_new"].str.replace(pat, '')
    df1["normalized_text_new"] = df1["normalized_text_new"].str.replace(r'\s+', ' ')
    return df1

# %%
bart = text_cleaning(val_bart)
homer = text_cleaning(val_homer)
marge = text_cleaning(val_marge)
lisa = text_cleaning(val_lisa)

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# ### **The top 20 words (unigrams-one word) spoken by the most popular characters**

# %%
common_words = get_top_n_words(bart['normalized_text_new'], 20)
common_words_df = pd.DataFrame (common_words,columns=['word','freq'])
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='word', y='freq', data=common_words_df,palette='OrRd')
plt.title("Top 20 unigrams used by Bart", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.yticks(fontsize=13)
plt.xticks(rotation=45, fontsize=13)
plt.xlabel("");

# %%
common_words = get_top_n_words(lisa['normalized_text_new'], 20)
common_words_df = pd.DataFrame(common_words,columns=['word','freq'])
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='word', y='freq', data=common_words_df,palette='PuRd')
plt.title("Top 20 unigrams used by Lisa", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.yticks(fontsize=13)
plt.xticks(rotation=45, fontsize=13)
plt.xlabel("");

# %%
common_words = get_top_n_words(homer['normalized_text_new'], 20)
common_words_df = pd.DataFrame(common_words,columns=['word','freq'])
plt.figure(figsize=(16, 7))
ax = sns.barplot(x='word', y='freq', data=common_words_df,palette='BuPu')
plt.title("Top 20 unigrams used by Homer", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.yticks(fontsize=13)
plt.xticks(rotation=45, fontsize=13)
plt.xlabel("");

# %%
common_words = get_top_n_words(marge['normalized_text_new'], 20)
common_words_df = pd.DataFrame (common_words,columns=['word','freq'])
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='word', y='freq', data=common_words_df,palette='GnBu')
plt.title("Top 20 unigrams used by Marge", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.yticks(fontsize=13)
plt.xticks(rotation=45, fontsize=13)
plt.xlabel("");

# %%
scripts.head()
# Out:
#      id  ...                                normalized_text_new
# 0  9549  ...  actually little sometimes disease magazine new...
# 1  9550  ...                                wheres mr bergstrom
# 2  9551  ...  dont know although id sure like talk didnt tou...
# 3  9552  ...                                  life worth living
# 4  9553  ...  poll open end recess case decided put thought ...
#
# [5 rows x 13 columns]

# %%
# find out the most frquent name which is not simpson
chars=pd.read_csv('characters.csv')
chars.head()
# Out:
#    id              name   normalized_name  sex
# 0   7          Children          children  NaN
# 1  12  Mechanical Santa  mechanical santa  NaN
# 2  13        Tattoo Man        tattoo man  NaN
# 3  16  DOCTOR ZITSOFSKY  doctor zitsofsky  NaN
# 4  20          Students          students  NaN

# %%
chars.shape
# Out:
# (6722, 5)

# %% [markdown]
#  **Since most of the 'sex' column in the chars dataset is empty, thus it would not be a contributing feature hence dropped**

# %%
chars['sex'].isnull().sum()
# Out:
# 6399

# %%
chars=chars.drop('sex',axis=1)

# %%
chars.head()
# Out:
#    id              name   normalized_name
# 0   7          Children          children
# 1  12  Mechanical Santa  mechanical santa
# 2  13        Tattoo Man        tattoo man
# 3  16  DOCTOR ZITSOFSKY  doctor zitsofsky
# 4  20          Students          students

# %% [markdown]
#  **Splitting the normalized_name into first_name and last_name so as to seggregate the different names to find out the most popular characters by frequency apart from the simpsons**

# %%
new=chars["normalized_name"].str.split(" ",n=1,expand=True)
chars["first_name"]=new[0]
chars["last_name"]=new[1]
chars
# Out:
#         id              name   normalized_name  first_name   last_name
# 0        7          Children          children    children        None
# 1       12  Mechanical Santa  mechanical santa  mechanical       santa
# 2       13        Tattoo Man        tattoo man      tattoo         man
# 3       16  DOCTOR ZITSOFSKY  doctor zitsofsky      doctor   zitsofsky
# 4       20          Students          students    students        None
# ...    ...               ...               ...         ...         ...
# 6717  5222    Ron Rabinowitz    ron rabinowitz         ron  rabinowitz
# 6718  5728    Martha Stewart    martha stewart      martha     stewart
# 6719  1770   Officer Goodman   officer goodman     officer     goodman
# 6720  1634      Evan Conover      evan conover        evan     conover
# 6721  1868     Agent Johnson     agent johnson       agent     johnson
#
# [6722 rows x 5 columns]

# %%
df_temp=chars.loc[chars['last_name'] !='simpsons']

# %%
df_temp.head()
# Out:
#    id              name   normalized_name  first_name  last_name
# 0   7          Children          children    children       None
# 1  12  Mechanical Santa  mechanical santa  mechanical      santa
# 2  13        Tattoo Man        tattoo man      tattoo        man
# 3  16  DOCTOR ZITSOFSKY  doctor zitsofsky      doctor  zitsofsky
# 4  20          Students          students    students       None

# %%
# sns.countplot(df_temp['first_name'],data=df_temp)
d=df_temp[df_temp.normalized_name== df_temp.normalized_name.max()]

# %%
d
# Out:
#         id  name normalized_name first_name last_name
# 1450  1483  Üter            Üter       Üter      None

# %% [markdown]
# **Üter is the most popular character apart from Simpsons**
